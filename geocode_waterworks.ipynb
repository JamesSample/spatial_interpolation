# %%
import pandas as pd
import folium
import geocoder

# %% [markdown]
# ## Geocode waterworks
#
# Isabel needs to identify geographic co-ordinates for Norwegian waterworks (see e-mail received 21/06/2017 at 10.31). This work is linked to Leah's DOMQUA project.
#
# It looks as though there's a problem with the UTM co-ordinates in Isabel's file. Instead, I've used Google geocoding API to find the nearest match. Note that I've had to modify the "search strings" in some cases to get a result.

# %%
# Read input data
in_xlsx = r'C:\Data\James_Work\Staff\Leah_JB\ECCO-DomQua\Geocode_Isabel\geocode_addresses.xlsx'
df = pd.read_excel(in_xlsx, sheetname='Sheet1')

df
# Out:
#                   vannverk    kommune                            kilde  \
# 0  Asker og Bærum vannverk      Bærum                      Holsfjorden
# 1         Glitrevannverket    Drammen                      Glittrevann
# 2     Flateby vannverk A/L    Enebakk                       Gjeddevann
# 3     Kornsjø vannverk A/L     Halden                 Nordre Kornsjøen
# 4                Haugesund  Haugesund  Stakkastadvatnet/Stakkestadvatn
# 5               Brekkevatn     Karmøy                       Brekkevatn
# 6  Oslo Vann og Avløpsverk       Oslo                   Maridalsvannet
# 7               Steinsvika      Skien                           Norsjø
# 8                    Hauge    Sokndal                    Guddalsvatnet
# 9         Ålesund vannverk    Ålesund                     Brusdalsvann
#
#                                           isabel_utm  \
# 0                                 32V 461632 6719696
# 1                                 32V 559414 6636588
# 2                               32V 618000Ø 6634380N
# 3                                 32V 653083 6534146
# 4                                 32V 294950 6597600
# 5  https://www.google.no/maps/place/S%C3%B8re+Bre...
# 6                                 32V 599236 6651022
# 7                                 32V 511424 6580577
# 8  https://www.google.no/maps/place/Guddalsvatnet...
# 9                                 32V 368873 6929763
#
#                             search_string
# 0  Asker og Bærum vannverk, Bærum, Norway
# 1       Glitrevannverket, Drammen, Norway
# 2   Flateby vannverk A/L, Enebakk, Norway
# 3                 Kornsjø, Halden, Norway
# 4     Stakkastadvatnet, Haugesund, Norway
# 5              Brekkevatn, Karmøy, Norway
# 6   Oslo Vann og Avløpsverk, Oslo, Norway
# 7               Steinsvika, Skien, Norway
# 8                  Hauge, Sokndal, Norway
# 9           Brusdalsvann, Ålesund, Norway

# %%
# Containers for lats and lons
lats = []
lons = []

# Loop over sites
for idx, row in df.iterrows():
    print 'Processing:', row['search_string']
    
    # Geocode address
    g = geocoder.google(row['search_string'])
    
    # Get lat and lon
    lat, lon = g.latlng
    lats.append(lat)
    lons.append(lon)

# Add to df
df['lat'] = lats
df['lon'] = lons

df
# Out:
# Processing: Asker og Bærum vannverk, Bærum, Norway
# Processing: Glitrevannverket, Drammen, Norway
# Processing: Flateby vannverk A/L, Enebakk, Norway
# Processing: Kornsjø, Halden, Norway
# Processing: Stakkastadvatnet, Haugesund, Norway
# Processing: Brekkevatn, Karmøy, Norway
# Processing: Oslo Vann og Avløpsverk, Oslo, Norway
# Processing: Steinsvika, Skien, Norway
# Processing: Hauge, Sokndal, Norway
# Processing: Brusdalsvann, Ålesund, Norway
#                   vannverk    kommune                            kilde  \
# 0  Asker og Bærum vannverk      Bærum                      Holsfjorden
# 1         Glitrevannverket    Drammen                      Glittrevann
# 2     Flateby vannverk A/L    Enebakk                       Gjeddevann
# 3     Kornsjø vannverk A/L     Halden                 Nordre Kornsjøen
# 4                Haugesund  Haugesund  Stakkastadvatnet/Stakkestadvatn
# 5               Brekkevatn     Karmøy                       Brekkevatn
# 6  Oslo Vann og Avløpsverk       Oslo                   Maridalsvannet
# 7               Steinsvika      Skien                           Norsjø
# 8                    Hauge    Sokndal                    Guddalsvatnet
# 9         Ålesund vannverk    Ålesund                     Brusdalsvann
#
#                                           isabel_utm  \
# 0                                 32V 461632 6719696
# 1                                 32V 559414 6636588
# 2                               32V 618000Ø 6634380N
# 3                                 32V 653083 6534146
# 4                                 32V 294950 6597600
# 5  https://www.google.no/maps/place/S%C3%B8re+Bre...
# 6                                 32V 599236 6651022
# 7                                 32V 511424 6580577
# 8  https://www.google.no/maps/place/Guddalsvatnet...
# 9                                 32V 368873 6929763
#
#                             search_string        lat        lon
# 0  Asker og Bærum vannverk, Bærum, Norway  59.894398  10.428302
# 1       Glitrevannverket, Drammen, Norway  59.689899  10.243657
# 2   Flateby vannverk A/L, Enebakk, Norway  59.830896  11.110100
# 3                 Kornsjø, Halden, Norway  58.941450  11.659869
# 4     Stakkastadvatnet, Haugesund, Norway  59.462204   5.376124
# 5              Brekkevatn, Karmøy, Norway  59.263689   5.262737
# 6   Oslo Vann og Avløpsverk, Oslo, Norway  59.919274  10.761914
# 7               Steinsvika, Skien, Norway  59.196174   9.515168
# 8                  Hauge, Sokndal, Norway  58.342349   6.277312
# 9           Brusdalsvann, Ålesund, Norway  62.478715   6.470804

# %%
# Setup map
map1 = folium.Map(location=[61, 10.8],
                  zoom_start=6,
                  tiles='Stamen Terrain')

# Add clickable markers for sites
for idx, row in df.iterrows():  
    folium.Marker([row['lat'], row['lon']], 
                  popup='%s (%s)' % (row['vannverk'], 
                                     row['kommune'])).add_to(map1)

map1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
